# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import matplotlib.pyplot as plt

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID                    City      Lat       Lng  Max Temp  Humidity  \
# 0        0             olonkinbyen  70.9221   -8.7187      3.08        89
# 1        1  hawaiian paradise park  19.5933 -154.9731     23.73        90
# 2        2               papatowai -46.5619  169.4708      7.33        70
# 3        3              georgetown   5.4112  100.3354     31.96        72
# 4        4           blackmans bay -43.0167  147.3167     15.29        75
#
#    Cloudiness  Wind Speed Country        Date
# 0          11        3.96      SJ  1697956727
# 1         100        2.57      US  1697956727
# 2           7        2.36      NZ  1697956728
# 3          40        5.14      MY  1697956728
# 4          24        3.40      AU  1697956729

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
x_values = city_data_df['Lng']
y_values = city_data_df['Lat']
humidity = city_data_df['Humidity'] 

# Plot cities on map accentuating humidity 
map_plot = city_data_df.hvplot.points(
    'Lng', 
    'Lat',
    size = 'Humidity',
    c = 'City',
    tiles = "OSM",
    geo = True
)

#display map
map_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
    #below 50% humidity
    #below 25 degrees Celsius
ideal_city_data_df = city_data_df[(city_data_df['Humidity'] <= 50) & (city_data_df['Max Temp'] <= 25)]

# Drop any rows with null values
ideal_city_data_df = ideal_city_data_df.dropna()

# Display sample data
ideal_city_data_df.head()
# Out:
#      City_ID        City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 40        40      chinde  26.8418   88.0763     23.17        47           0
# 77        77  constantia  44.1833   28.6500     23.17        47           5
# 91        91     lijiang  26.8688  100.2207     19.56        26           0
# 95        95     sarkand  45.4100   79.9186     20.20        36          36
# 120      120      zaysan  47.4667   84.8667     15.19        48          73
#
#      Wind Speed Country        Date
# 40         1.95      NP  1697956749
# 77         3.34      RO  1697956770
# 91         2.34      CN  1697956779
# 95         2.21      KZ  1697956782
# 120        3.05      KZ  1697956797

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_city_data_df[['City','Country','Lat','Lng','Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ""

# Display sample data
hotel_df.head()
# Out:
#            City Country      Lat       Lng  Humidity Hotel Name
# 40       chinde      NP  26.8418   88.0763        47
# 77   constantia      RO  44.1833   28.6500        47
# 91      lijiang      CN  26.8688  100.2207        26
# 95      sarkand      KZ  45.4100   79.9186        36
# 120      zaysan      KZ  47.4667   84.8667        48

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000 #(10 km)
params = {
    "apiKey":geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude= row['Lat']
    longitude = row['Lng']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    params["categories"] = f"accommodation.hotel"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df.head()
# Out:
# Starting hotel search
# chinde - nearest hotel: Kanyum cottage village
# constantia - nearest hotel: Hotel Chérica
# lijiang - nearest hotel: 阿丹阁大酒店
# sarkand - nearest hotel: Сарканд
# zaysan - nearest hotel: Рахат қонақүй
# hovd - nearest hotel: Khovd hotel
# butembo - nearest hotel: Canada House
# klyuchi - nearest hotel: No hotel found
# qaqortoq - nearest hotel: Hotel Qaqortoq
# flagstaff - nearest hotel: Residence Inn
# erenhot - nearest hotel: Oulen hotel
# calama - nearest hotel: Apart Hotel Geotel Calama
# xilin hot - nearest hotel: Hotel hailibu 120
# nishinoomote - nearest hotel: ゼウスハウス
# oyama - nearest hotel: 東横イン 小山駅東口1
# dzuunmod - nearest hotel: No hotel found
# miles city - nearest hotel: Historic Olive Hotel
# guiren - nearest hotel: No hotel found
# sinop - nearest hotel: No hotel found
# al qaryatayn - nearest hotel: No hotel found
# hotan - nearest hotel: Hua Yi International Hotel (accepts foreigners)
# ekibastuz - nearest hotel: General
# buka - nearest hotel: No hotel found
# crane - nearest hotel: No hotel found
# baishishan - nearest hotel: No hotel found
# mhamid - nearest hotel: Hotel Kasbah Azalay
# xining - nearest hotel: Qinghai hotel
# suzaka - nearest hotel: サンシャインエイト
# belyy yar - nearest hotel: No hotel found
# ceadir-lunga - nearest hotel: Марица
# hami - nearest hotel: Хами
# mogocha - nearest hotel: 7Ka
# moreni - nearest hotel: Hotel Central
# lhasa - nearest hotel: Shangri-la Hotel Lhasa
# arkhara - nearest hotel: No hotel found
# asau - nearest hotel: Hotel Romanița
# karatau - nearest hotel: Артабас
# borzya - nearest hotel: гостиница Глория
# bardai - nearest hotel: No hotel found
# ulety - nearest hotel: No hotel found
# kuanda - nearest hotel: No hotel found
# luocheng - nearest hotel: No hotel found
# tekeli - nearest hotel: Гостиница Айсберг
# recani - nearest hotel: Hotel Merzouga
# zanjan - nearest hotel: Amir Kabir
# sao vicente - nearest hotel: Pousada Vitória
# anqing - nearest hotel: 安庆大酒店
# nikolayevsk-on-amure - nearest hotel: Север
# nagqu - nearest hotel: Naqu Hotel
# aral - nearest hotel: No hotel found
# tamanrasset - nearest hotel: فندق الأمان
# damascus - nearest hotel: فندق دار السلام
# zeya - nearest hotel: Серебряный створ
# tiquipaya - nearest hotel: Hotel Regina Resort & Convenciones
#            City Country      Lat       Lng  Humidity              Hotel Name
# 40       chinde      NP  26.8418   88.0763        47  Kanyum cottage village
# 77   constantia      RO  44.1833   28.6500        47           Hotel Chérica
# 91      lijiang      CN  26.8688  100.2207        26                  阿丹阁大酒店
# 95      sarkand      KZ  45.4100   79.9186        36                 Сарканд
# 120      zaysan      KZ  47.4667   84.8667        48           Рахат қонақүй

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
x_values = hotel_df['Lng']
y_values = hotel_df['Lat']
humidity = hotel_df['Humidity'] 

# Plot cities on map accentuating humidity 
map_plot = hotel_df.hvplot.points(
    'Lng', 
    'Lat',
    size = 'Humidity',
    c = 'City',
    tiles = "OSM",
    geo = True,
    hover_cols=['City','Country', 'Hotel Name']
)

#display map
map_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Country,Hotel Name)
